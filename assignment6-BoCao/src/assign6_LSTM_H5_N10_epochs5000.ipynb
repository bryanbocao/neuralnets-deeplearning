# %%
"""
Author: Bryan Bo Cao
Email: boca7588@colorado.edu or bo.cao-1@colorado.edu
Github Repo: https://github.com/BryanBo-Cao/neuralnets-deeplearning
Reference:
    http://www.deeplearning.net/tutorial/lstm.html#lstm
    https://github.com/llSourcell/LSTM_Networks/blob/master/LSTM%20Demo.ipynb
    https://github.com/aymericdamien/TensorFlow-Examples/blob/master/examples/3_NeuralNetworks/recurrent_network.py
    Recurrent Neural Network.
    A Recurrent Neural Network (LSTM) implementation example using TensorFlow library.
    This example is using the MNIST database of handwritten digits (http://yann.lecun.com/exdb/mnist/)
    Links:
    [Long Short Term Memory](http://deeplearning.cs.cmu.edu/pdfs/Hochreiter97_lstm.pdf)
    [MNIST Dataset](http://yann.lecun.com/exdb/mnist/).
    Author: Aymeric Damien
    Project: https://github.com/aymericdamien/TensorFlow-Examples/
"""
from __future__ import print_function

import tensorflow as tf
from tensorflow.contrib import rnn
import numpy as np
import random
import copy
import matplotlib.pyplot as plt
from importlib import import_module

H = 5
N = 10

#Reference: Denis
def generate_parity_sequences(N, count):
    """
    Generate :count: sequences of length :N:.
    If odd # of 1's -> output 1
    else -> output 0
    """
    xor = lambda x: 1 if (x % 2 == 1) else 0
    sequences = np.random.choice([0, 1], size=[count, N], replace=True)
    counts = np.count_nonzero(sequences == 1, axis=1)
    # xor each sequence, expand dimensions by 1 to match sequences shape
    y = np.expand_dims(np.array([xor(x) for x in counts]), axis=1)

    # In case if you wanted to have the answer just appended at the end of the sequence:
    #     # append the answer at the end of each sequence
    #     seq_plus_y = np.concatenate([sequences, y], axis=1)
    #     print(sequences.shape, y.shape, seq_plus_y.shape)
    #     return seq_plus_y
    return np.expand_dims(sequences, axis=2), y

#Reference: Modified from Denis by Bo Cao
def generate_parity_sequences(N, count):
    """
    Generate :count: sequences of length :N:.
    If odd # of 1's -> output 1
    else -> output 0
    """
    xor = lambda x: 1 if (x % 2 == 1) else 0
    sequences = np.random.choice([0, 1], size=[count, N], replace=True)
    counts = np.count_nonzero(sequences == 1, axis=1)
    # xor each sequence, expand dimensions by 1 to match sequences shape
    y = np.expand_dims(np.array([xor(x) for x in counts]), axis=1)

    # In case if you wanted to have the answer just appended at the end of the sequence:
    #     # append the answer at the end of each sequence
    #     seq_plus_y = np.concatenate([sequences, y], axis=1)
    #     print(sequences.shape, y.shape, seq_plus_y.shape)
    #     return seq_plus_y
    
    new_y = []
    for i in range(len(y)):
        new_yy = []
        if y[i] == 0:
            new_yy.append(0)
            new_yy.append(1)
        else:
            new_yy.append(1)
            new_yy.append(0)
        new_y.append(new_yy)

    return np.expand_dims(sequences, axis=2), new_y

# %%
# Training Parameters
learning_rate = 0.35
batch_size = 128
display_step = batch_size * 100

#batch_steps = 10000 / batch_size
epochs = 5000

# Network Parameters
num_input = 1 # 
timesteps = N # timesteps
num_hidden = H # hidden layer num of features
num_classes = 2 # 0 or 1

# tf Graph input
X = tf.placeholder("float", [None, timesteps, num_input])
Y = tf.placeholder("float", [None, num_classes])

# Define weights
weights = {
    'out': tf.Variable(tf.random_normal([num_hidden, num_classes]))
}
biases = {
    'out': tf.Variable(tf.random_normal([num_classes]))
}


def RNN(x, weights, biases):

    # Prepare data shape to match `rnn` function requirements
    # Current data input shape: (batch_size, timesteps, n_input)
    # Required shape: 'timesteps' tensors list of shape (batch_size, n_input)

    # Unstack to get a list of 'timesteps' tensors of shape (batch_size, n_input)
    x = tf.unstack(x, timesteps, 1)

    # Define a lstm cell with tensorflow
    lstm_cell = rnn.BasicLSTMCell(num_hidden, forget_bias=1.0)

    # Get lstm cell output
    outputs, states = rnn.static_rnn(lstm_cell, x, dtype=tf.float32)

    # Linear activation, using rnn inner loop last output
    return tf.matmul(outputs[-1], weights['out']) + biases['out']

logits = RNN(X, weights, biases)
#prediction = tf.nn.softmax(logits)
prediction = tf.tanh(logits)

# Define loss and optimizer
loss_op = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(
    logits=logits, labels=Y))
optimizer = tf.train.GradientDescentOptimizer(learning_rate=learning_rate)
train_op = optimizer.minimize(loss_op)

# Evaluate model (with test logits, for dropout to be disabled)
correct_pred = tf.equal(tf.argmax(prediction, 1), tf.argmax(Y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32))

# Initialize the variables (i.e. assign their default value)
init = tf.global_variables_initializer()

test_accuracies_10replications = []
minibatch_losses_1st_replication = [] #epoch as unit
test_accuracies_1st_replication = [] #epoch as unit
train_accuracies_1st_replication = [] #epoch as unit

# Start training
with tf.Session() as sess:
    
    # Run 10 replications
    for replication in range(10):
        
        print("Replication: %d: " % replication)
        
        # Initialize random weights
        train_data = generate_parity_sequences(N, 10000)
        train_data_x = train_data[0]
        train_data_y = train_data[1]
        test_data = generate_parity_sequences(N, 10000)
        test_data_x = test_data[0]
        test_data_y = test_data[1]
        
        # Run the initializer
        sess.run(init)
    
        for epoch in range(epochs):
            batch_index = 0
            while batch_index < 10000:

                train_data_batch_x = []
                train_data_batch_y = []
                if batch_index + batch_size < 10000: 
                    train_data_batch_x = train_data_x[batch_index : batch_index + batch_size]
                    train_data_batch_y = train_data_y[batch_index : batch_index + batch_size]
                else:
                    train_data_batch_x = train_data_x[batch_index : ]
                    train_data_batch_y = train_data_y[batch_index : ]

                #batch_x, batch_y = mnist.train.next_batch(batch_size)
                # Reshape data to get 28 seq of 28 elements
                #batch_x = batch_x.reshape((batch_size, timesteps, num_input))
                #train_data_x = train_data_x.reshape((10000, timesteps, num_input))
                #print("train_data_batch_x.shape:  " , train_data_batch_x.shape)
                if batch_index + batch_size < 10000: 
                    train_data_batch_x = train_data_batch_x.reshape((batch_size, timesteps, num_input))
                else:
                    train_data_batch_x = train_data_batch_x.reshape((10000 % batch_size, timesteps, num_input))
                # Run optimization op (backprop)
                #sess.run(train_op, feed_dict={X: train_data_x, 
                 #                             Y: train_data_y})
                sess.run(train_op, feed_dict={X: train_data_batch_x, 
                                              Y: train_data_batch_y})

                batch_index += batch_size

            if replication == 0:
                loss, train_accuracy = sess.run([loss_op, accuracy], feed_dict={X: train_data_x, Y: train_data_y})
                test_accuracy = sess.run(accuracy, feed_dict={X: test_data_x, Y: test_data_y})
                minibatch_losses_1st_replication.append(loss)
                train_accuracies_1st_replication.append(train_accuracy)
                test_accuracies_1st_replication.append(test_accuracy)
            
            if epoch % 10 == 0:
                loss, acc = sess.run([loss_op, accuracy], feed_dict={X: train_data_x,
                                                                         Y: train_data_y})
                print("Epoch: " + str(epoch) + \
                          ", Minibatch Loss= " + \
                          "{:.4f}".format(loss) + ", Training Accuracy= " + \
                          "{:.3f}".format(acc))

        print("Optimization Finished!")

        test_data_x = test_data_x.reshape((-1, timesteps, num_input))
        test_data_y = test_data_y
        test_accuracy = sess.run(accuracy, feed_dict={X: test_data_x, Y: test_data_y})
        test_accuracies_10replications.append(test_accuracy)
        print("Testing Accuracy:", test_accuracy)
# Out:
# Replication: 0:
# Epoch: 0, Minibatch Loss= 0.6955, Training Accuracy= 0.511
# Epoch: 10, Minibatch Loss= 0.6938, Training Accuracy= 0.511
# Epoch: 20, Minibatch Loss= 0.6936, Training Accuracy= 0.511
# Epoch: 30, Minibatch Loss= 0.6935, Training Accuracy= 0.511
# Epoch: 40, Minibatch Loss= 0.6934, Training Accuracy= 0.511
# Epoch: 50, Minibatch Loss= 0.6934, Training Accuracy= 0.511
# Epoch: 60, Minibatch Loss= 0.6933, Training Accuracy= 0.511
# Epoch: 70, Minibatch Loss= 0.6933, Training Accuracy= 0.511
# Epoch: 80, Minibatch Loss= 0.6933, Training Accuracy= 0.511
# Epoch: 90, Minibatch Loss= 0.6932, Training Accuracy= 0.511
# Epoch: 100, Minibatch Loss= 0.6932, Training Accuracy= 0.511
# Epoch: 110, Minibatch Loss= 0.6932, Training Accuracy= 0.511
# Epoch: 120, Minibatch Loss= 0.6932, Training Accuracy= 0.511
# Epoch: 130, Minibatch Loss= 0.6932, Training Accuracy= 0.511
# Epoch: 140, Minibatch Loss= 0.6932, Training Accuracy= 0.511
# Epoch: 150, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 160, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 170, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 180, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 190, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 200, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 210, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 220, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 230, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 240, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 250, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 260, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 270, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 280, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 290, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 300, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 310, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 320, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 330, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 340, Minibatch Loss= 0.6931, Training Accuracy= 0.511
# Epoch: 350, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 360, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 370, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 380, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 390, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 400, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 410, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 420, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 430, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 440, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 450, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 460, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 470, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 480, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 490, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 500, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 510, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 520, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 530, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 540, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 550, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 560, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 570, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 580, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 590, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 600, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 610, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 620, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 630, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 640, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 650, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 660, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 670, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 680, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 690, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 700, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 710, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 720, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 730, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 740, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 750, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 760, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 770, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 780, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 790, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 800, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 810, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 820, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 830, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 840, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 850, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 860, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 870, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 880, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 890, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 900, Minibatch Loss= 0.6930, Training Accuracy= 0.511
# Epoch: 910, Minibatch Loss= 0.6929, Training Accuracy= 0.511
# Epoch: 920, Minibatch Loss= 0.6929, Training Accuracy= 0.511
# Epoch: 930, Minibatch Loss= 0.6929, Training Accuracy= 0.511
# Epoch: 940, Minibatch Loss= 0.6929, Training Accuracy= 0.511
# Epoch: 950, Minibatch Loss= 0.6929, Training Accuracy= 0.511
# Epoch: 960, Minibatch Loss= 0.6928, Training Accuracy= 0.511
# Epoch: 970, Minibatch Loss= 0.6924, Training Accuracy= 0.507
# Epoch: 980, Minibatch Loss= 0.6863, Training Accuracy= 0.586
# Epoch: 990, Minibatch Loss= 0.4532, Training Accuracy= 0.798
# Epoch: 1000, Minibatch Loss= 0.2070, Training Accuracy= 0.912
# Epoch: 1010, Minibatch Loss= 0.1395, Training Accuracy= 0.929
# Epoch: 1020, Minibatch Loss= 0.0892, Training Accuracy= 0.971
# Epoch: 1030, Minibatch Loss= 0.0754, Training Accuracy= 0.979
# Epoch: 1040, Minibatch Loss= 0.0695, Training Accuracy= 0.979
# Epoch: 1050, Minibatch Loss= 0.0659, Training Accuracy= 0.979
# Epoch: 1060, Minibatch Loss= 0.0631, Training Accuracy= 0.980
# Epoch: 1070, Minibatch Loss= 0.0595, Training Accuracy= 0.980
# Epoch: 1080, Minibatch Loss= 0.0547, Training Accuracy= 0.977
# Epoch: 1090, Minibatch Loss= 0.0502, Training Accuracy= 0.978
# Epoch: 1100, Minibatch Loss= 0.0459, Training Accuracy= 0.979
# Epoch: 1110, Minibatch Loss= 0.0413, Training Accuracy= 0.981
# Epoch: 1120, Minibatch Loss= 0.0371, Training Accuracy= 0.986
# Epoch: 1130, Minibatch Loss= 0.0338, Training Accuracy= 0.989
# Epoch: 1140, Minibatch Loss= 0.0315, Training Accuracy= 0.991
# Epoch: 1150, Minibatch Loss= 0.0292, Training Accuracy= 0.993
# Epoch: 1160, Minibatch Loss= 0.8421, Training Accuracy= 0.505
# Epoch: 1170, Minibatch Loss= 0.7717, Training Accuracy= 0.505
# Epoch: 1180, Minibatch Loss= 0.7493, Training Accuracy= 0.505
# Epoch: 1190, Minibatch Loss= 0.7402, Training Accuracy= 0.505
# Epoch: 1200, Minibatch Loss= 0.7349, Training Accuracy= 0.505
# Epoch: 1210, Minibatch Loss= 0.7311, Training Accuracy= 0.505
# Epoch: 1220, Minibatch Loss= 0.7282, Training Accuracy= 0.505
# Epoch: 1230, Minibatch Loss= 0.7259, Training Accuracy= 0.505
# Epoch: 1240, Minibatch Loss= 0.7240, Training Accuracy= 0.505
# Epoch: 1250, Minibatch Loss= 0.7224, Training Accuracy= 0.505
# Epoch: 1260, Minibatch Loss= 0.7209, Training Accuracy= 0.505
# Epoch: 1270, Minibatch Loss= 0.7197, Training Accuracy= 0.505
# Epoch: 1280, Minibatch Loss= 0.7185, Training Accuracy= 0.505
# Epoch: 1290, Minibatch Loss= 0.7175, Training Accuracy= 0.505
# Epoch: 1300, Minibatch Loss= 0.7165, Training Accuracy= 0.505
# Epoch: 1310, Minibatch Loss= 0.7156, Training Accuracy= 0.505
# Epoch: 1320, Minibatch Loss= 0.7149, Training Accuracy= 0.505
# Epoch: 1330, Minibatch Loss= 0.7140, Training Accuracy= 0.505
# Epoch: 1340, Minibatch Loss= 0.7129, Training Accuracy= 0.505
# Epoch: 1350, Minibatch Loss= 0.7115, Training Accuracy= 0.505
# Epoch: 1360, Minibatch Loss= 0.7105, Training Accuracy= 0.506
# Epoch: 1370, Minibatch Loss= 0.7097, Training Accuracy= 0.505
# Epoch: 1380, Minibatch Loss= 0.7101, Training Accuracy= 0.504
# Epoch: 1390, Minibatch Loss= 0.7101, Training Accuracy= 0.505
# Epoch: 1400, Minibatch Loss= 0.7096, Training Accuracy= 0.505
# Epoch: 1410, Minibatch Loss= 0.7088, Training Accuracy= 0.505
# Epoch: 1420, Minibatch Loss= 0.7080, Training Accuracy= 0.505
# Epoch: 1430, Minibatch Loss= 0.7073, Training Accuracy= 0.505
# Epoch: 1440, Minibatch Loss= 0.7067, Training Accuracy= 0.505
# Epoch: 1450, Minibatch Loss= 0.7062, Training Accuracy= 0.505
# Epoch: 1460, Minibatch Loss= 0.7059, Training Accuracy= 0.505
# Epoch: 1470, Minibatch Loss= 0.7058, Training Accuracy= 0.505
# Epoch: 1480, Minibatch Loss= 0.7062, Training Accuracy= 0.504
# Epoch: 1490, Minibatch Loss= 0.7077, Training Accuracy= 0.506
# Epoch: 1500, Minibatch Loss= 0.7087, Training Accuracy= 0.507
# Epoch: 1510, Minibatch Loss= 0.7028, Training Accuracy= 0.509
# Epoch: 1520, Minibatch Loss= 0.7036, Training Accuracy= 0.507
# Epoch: 1530, Minibatch Loss= 0.7047, Training Accuracy= 0.506
# Epoch: 1540, Minibatch Loss= 0.7056, Training Accuracy= 0.507
# Epoch: 1550, Minibatch Loss= 0.7051, Training Accuracy= 0.506
# Epoch: 1560, Minibatch Loss= 0.7009, Training Accuracy= 0.517
# Epoch: 1570, Minibatch Loss= 0.6950, Training Accuracy= 0.501
# Epoch: 1580, Minibatch Loss= 0.6938, Training Accuracy= 0.502
# Epoch: 1590, Minibatch Loss= 0.6932, Training Accuracy= 0.505
# Epoch: 1600, Minibatch Loss= 0.6927, Training Accuracy= 0.506
# Epoch: 1610, Minibatch Loss= 0.6925, Training Accuracy= 0.507
# Epoch: 1620, Minibatch Loss= 0.6923, Training Accuracy= 0.510
# Epoch: 1630, Minibatch Loss= 0.6922, Training Accuracy= 0.510
# Epoch: 1640, Minibatch Loss= 0.6920, Training Accuracy= 0.512
# Epoch: 1650, Minibatch Loss= 0.6917, Training Accuracy= 0.512
# Epoch: 1660, Minibatch Loss= 0.6913, Training Accuracy= 0.510
# Epoch: 1670, Minibatch Loss= 0.6916, Training Accuracy= 0.510
# Epoch: 1680, Minibatch Loss= 0.6909, Training Accuracy= 0.510
# Epoch: 1690, Minibatch Loss= 0.6899, Training Accuracy= 0.511
# Epoch: 1700, Minibatch Loss= 0.6895, Training Accuracy= 0.511
# Epoch: 1710, Minibatch Loss= 0.6889, Training Accuracy= 0.512
# Epoch: 1720, Minibatch Loss= 0.6875, Training Accuracy= 0.516
# Epoch: 1730, Minibatch Loss= 0.6866, Training Accuracy= 0.513
# Epoch: 1740, Minibatch Loss= 0.6857, Training Accuracy= 0.514
# Epoch: 1750, Minibatch Loss= 0.6849, Training Accuracy= 0.515
# Epoch: 1760, Minibatch Loss= 0.6849, Training Accuracy= 0.514
# Epoch: 1770, Minibatch Loss= 0.6852, Training Accuracy= 0.516
# Epoch: 1780, Minibatch Loss= 0.6854, Training Accuracy= 0.515
# Epoch: 1790, Minibatch Loss= 0.6851, Training Accuracy= 0.514
# Epoch: 1800, Minibatch Loss= 0.6842, Training Accuracy= 0.515
# Epoch: 1810, Minibatch Loss= 0.6833, Training Accuracy= 0.513
# Epoch: 1820, Minibatch Loss= 0.6824, Training Accuracy= 0.521
# Epoch: 1830, Minibatch Loss= 0.6810, Training Accuracy= 0.530
# Epoch: 1840, Minibatch Loss= 0.6850, Training Accuracy= 0.528
# Epoch: 1850, Minibatch Loss= 0.6888, Training Accuracy= 0.533
# Epoch: 1860, Minibatch Loss= 0.6892, Training Accuracy= 0.533
# Epoch: 1870, Minibatch Loss= 0.6857, Training Accuracy= 0.546
# Epoch: 1880, Minibatch Loss= 0.6864, Training Accuracy= 0.549
# Epoch: 1890, Minibatch Loss= 0.6849, Training Accuracy= 0.551
# Epoch: 1900, Minibatch Loss= 0.6844, Training Accuracy= 0.550
# Epoch: 1910, Minibatch Loss= 0.7041, Training Accuracy= 0.550
# Epoch: 1920, Minibatch Loss= 0.6770, Training Accuracy= 0.555
# Epoch: 1930, Minibatch Loss= 0.6774, Training Accuracy= 0.566
# Epoch: 1940, Minibatch Loss= 0.6765, Training Accuracy= 0.560
# Epoch: 1950, Minibatch Loss= 0.6670, Training Accuracy= 0.568
# Epoch: 1960, Minibatch Loss= 0.6686, Training Accuracy= 0.565
# Epoch: 1970, Minibatch Loss= 0.6793, Training Accuracy= 0.564
# Epoch: 1980, Minibatch Loss= 0.6653, Training Accuracy= 0.575
# Epoch: 1990, Minibatch Loss= 0.6727, Training Accuracy= 0.573
# Epoch: 2000, Minibatch Loss= 0.6620, Training Accuracy= 0.605
# Epoch: 2010, Minibatch Loss= 0.6214, Training Accuracy= 0.636
# Epoch: 2020, Minibatch Loss= 0.8718, Training Accuracy= 0.580
# Epoch: 2030, Minibatch Loss= 0.7153, Training Accuracy= 0.549
# Epoch: 2040, Minibatch Loss= 0.6854, Training Accuracy= 0.571
# Epoch: 2050, Minibatch Loss= 0.6434, Training Accuracy= 0.615
# Epoch: 2060, Minibatch Loss= 0.6615, Training Accuracy= 0.615
# Epoch: 2070, Minibatch Loss= 0.6598, Training Accuracy= 0.610
# Epoch: 2080, Minibatch Loss= 0.5996, Training Accuracy= 0.662
# Epoch: 2090, Minibatch Loss= 0.6001, Training Accuracy= 0.663
# Epoch: 2100, Minibatch Loss= 0.5808, Training Accuracy= 0.685
# Epoch: 2110, Minibatch Loss= 0.6706, Training Accuracy= 0.530
# Epoch: 2120, Minibatch Loss= 0.6659, Training Accuracy= 0.535
# Epoch: 2130, Minibatch Loss= 0.6603, Training Accuracy= 0.560
# Epoch: 2140, Minibatch Loss= 0.6498, Training Accuracy= 0.581
# Epoch: 2150, Minibatch Loss= 0.6452, Training Accuracy= 0.593
# Epoch: 2160, Minibatch Loss= 0.6407, Training Accuracy= 0.596
# Epoch: 2170, Minibatch Loss= 0.6369, Training Accuracy= 0.603
# Epoch: 2180, Minibatch Loss= 0.6340, Training Accuracy= 0.613
# Epoch: 2190, Minibatch Loss= 0.6357, Training Accuracy= 0.606
# Epoch: 2200, Minibatch Loss= 0.6599, Training Accuracy= 0.663
# Epoch: 2210, Minibatch Loss= 0.1146, Training Accuracy= 0.978
# Epoch: 2220, Minibatch Loss= 0.0494, Training Accuracy= 0.992
# Epoch: 2230, Minibatch Loss= 0.0423, Training Accuracy= 0.993
# Epoch: 2240, Minibatch Loss= 0.0396, Training Accuracy= 0.993
# Epoch: 2250, Minibatch Loss= 0.0329, Training Accuracy= 0.994
# Epoch: 2260, Minibatch Loss= 0.0327, Training Accuracy= 0.994
# Epoch: 2270, Minibatch Loss= 0.0125, Training Accuracy= 0.999
# Epoch: 2280, Minibatch Loss= 0.0105, Training Accuracy= 0.999
# Epoch: 2290, Minibatch Loss= 0.0094, Training Accuracy= 0.999
# Epoch: 2300, Minibatch Loss= 0.0086, Training Accuracy= 0.999
# Epoch: 2310, Minibatch Loss= 0.0079, Training Accuracy= 0.999
# Epoch: 2320, Minibatch Loss= 0.0073, Training Accuracy= 0.999
# Epoch: 2330, Minibatch Loss= 0.0068, Training Accuracy= 0.999
# Epoch: 2340, Minibatch Loss= 0.0063, Training Accuracy= 0.999
# Epoch: 2350, Minibatch Loss= 0.0058, Training Accuracy= 0.999
# Epoch: 2360, Minibatch Loss= 0.0053, Training Accuracy= 0.999
# Epoch: 2370, Minibatch Loss= 0.0049, Training Accuracy= 0.999
# Epoch: 2380, Minibatch Loss= 0.0044, Training Accuracy= 0.999
# Epoch: 2390, Minibatch Loss= 0.0040, Training Accuracy= 0.999
# Epoch: 2400, Minibatch Loss= 0.0037, Training Accuracy= 0.999
# Epoch: 2410, Minibatch Loss= 0.0033, Training Accuracy= 0.999
# Epoch: 2420, Minibatch Loss= 0.0030, Training Accuracy= 0.999
# Epoch: 2430, Minibatch Loss= 0.0026, Training Accuracy= 0.999
# Epoch: 2440, Minibatch Loss= 0.0019, Training Accuracy= 1.000
# Epoch: 2450, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Epoch: 2460, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Epoch: 2470, Minibatch Loss= 0.0013, Training Accuracy= 1.000
# Epoch: 2480, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Epoch: 2490, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Epoch: 2500, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Epoch: 2510, Minibatch Loss= 0.0009, Training Accuracy= 1.000
# Epoch: 2520, Minibatch Loss= 0.0009, Training Accuracy= 1.000
# Epoch: 2530, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Epoch: 2540, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Epoch: 2550, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Epoch: 2560, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Epoch: 2570, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Epoch: 2580, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Epoch: 2590, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Epoch: 2600, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 2610, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 2620, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 2630, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 2640, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 2650, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 2660, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 2670, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 2680, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 2690, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 2700, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 2710, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 2720, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 2730, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 2740, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2750, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2760, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2770, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2780, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2790, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2800, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2810, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2820, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2830, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2840, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2850, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2860, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 2870, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2880, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2890, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2900, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2910, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2920, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2930, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2940, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2950, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2960, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2970, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2980, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 2990, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3000, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3010, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3020, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3030, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3040, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3050, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3060, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3070, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3080, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 3090, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3100, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3110, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3120, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3130, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3140, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3150, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3160, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3170, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3180, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3190, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3200, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3210, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3220, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3230, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3240, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3250, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3260, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3270, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3280, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3290, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3300, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3310, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3320, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3330, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3340, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3350, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3360, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3370, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3380, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3390, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3400, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3410, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3420, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3430, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3440, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3450, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3460, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3470, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3480, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3490, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3500, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3510, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3520, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3530, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3540, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3550, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3560, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3570, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3580, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3590, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3600, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 3610, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3620, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3630, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3640, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3650, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3660, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3670, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3680, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3690, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3700, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3710, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3720, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3730, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3740, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3750, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3760, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3770, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3780, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3790, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3800, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3810, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3820, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3830, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3840, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3850, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3860, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3870, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3880, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3890, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3900, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3910, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3920, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3930, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3940, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3950, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3960, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3970, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3980, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 3990, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4000, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4010, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4020, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4030, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4040, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4050, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4060, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4070, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4080, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4090, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4100, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4110, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4120, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4130, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4140, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4150, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4160, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4170, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4180, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4190, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4200, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4210, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4220, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4230, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4240, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4250, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4260, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4270, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4280, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4290, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4300, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4310, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4320, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4330, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4340, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4350, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4360, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4370, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4380, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4390, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4400, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4410, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4420, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4430, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4440, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4450, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4460, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4470, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4480, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4490, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4500, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4510, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4520, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4530, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4540, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4550, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4560, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4570, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4580, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4590, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4600, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4610, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4620, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4630, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4640, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4650, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4660, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4670, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4680, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4690, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4700, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4710, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4720, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4730, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4740, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4750, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4760, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4770, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4780, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4790, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4800, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4810, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4820, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4830, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4840, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4850, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4860, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4870, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4880, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4890, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4900, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4910, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4920, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4930, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4940, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4950, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4960, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4970, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4980, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 4990, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Optimization Finished!
# Testing Accuracy: 1.0
# Replication: 1:
# Epoch: 0, Minibatch Loss= 0.6979, Training Accuracy= 0.500
# Epoch: 10, Minibatch Loss= 0.6946, Training Accuracy= 0.500
# Epoch: 20, Minibatch Loss= 0.6940, Training Accuracy= 0.500
# Epoch: 30, Minibatch Loss= 0.6938, Training Accuracy= 0.500
# Epoch: 40, Minibatch Loss= 0.6936, Training Accuracy= 0.501
# Epoch: 50, Minibatch Loss= 0.6935, Training Accuracy= 0.500
# Epoch: 60, Minibatch Loss= 0.6934, Training Accuracy= 0.502
# Epoch: 70, Minibatch Loss= 0.6934, Training Accuracy= 0.499
# Epoch: 80, Minibatch Loss= 0.6934, Training Accuracy= 0.494
# Epoch: 90, Minibatch Loss= 0.6933, Training Accuracy= 0.500
# Epoch: 100, Minibatch Loss= 0.6933, Training Accuracy= 0.506
# Epoch: 110, Minibatch Loss= 0.6933, Training Accuracy= 0.510
# Epoch: 120, Minibatch Loss= 0.6932, Training Accuracy= 0.511
# Epoch: 130, Minibatch Loss= 0.6932, Training Accuracy= 0.509
# Epoch: 140, Minibatch Loss= 0.6932, Training Accuracy= 0.509
# Epoch: 150, Minibatch Loss= 0.6932, Training Accuracy= 0.507
# Epoch: 160, Minibatch Loss= 0.6932, Training Accuracy= 0.507
# Epoch: 170, Minibatch Loss= 0.6932, Training Accuracy= 0.503
# Epoch: 180, Minibatch Loss= 0.6932, Training Accuracy= 0.503
# Epoch: 190, Minibatch Loss= 0.6931, Training Accuracy= 0.507
# Epoch: 200, Minibatch Loss= 0.6931, Training Accuracy= 0.506
# Epoch: 210, Minibatch Loss= 0.6931, Training Accuracy= 0.504
# Epoch: 220, Minibatch Loss= 0.6931, Training Accuracy= 0.506
# Epoch: 230, Minibatch Loss= 0.6931, Training Accuracy= 0.508
# Epoch: 240, Minibatch Loss= 0.6931, Training Accuracy= 0.508
# Epoch: 250, Minibatch Loss= 0.6931, Training Accuracy= 0.507
# Epoch: 260, Minibatch Loss= 0.6931, Training Accuracy= 0.507
# Epoch: 270, Minibatch Loss= 0.6931, Training Accuracy= 0.506
# Epoch: 280, Minibatch Loss= 0.6931, Training Accuracy= 0.506
# Epoch: 290, Minibatch Loss= 0.6931, Training Accuracy= 0.506
# Epoch: 300, Minibatch Loss= 0.6930, Training Accuracy= 0.505
# Epoch: 310, Minibatch Loss= 0.6930, Training Accuracy= 0.505
# Epoch: 320, Minibatch Loss= 0.6930, Training Accuracy= 0.507
# Epoch: 330, Minibatch Loss= 0.6930, Training Accuracy= 0.510
# Epoch: 340, Minibatch Loss= 0.6930, Training Accuracy= 0.512
# Epoch: 350, Minibatch Loss= 0.6930, Training Accuracy= 0.509
# Epoch: 360, Minibatch Loss= 0.6930, Training Accuracy= 0.498
# Epoch: 370, Minibatch Loss= 0.6929, Training Accuracy= 0.496
# Epoch: 380, Minibatch Loss= 0.6929, Training Accuracy= 0.495
# Epoch: 390, Minibatch Loss= 0.6929, Training Accuracy= 0.507
# Epoch: 400, Minibatch Loss= 0.6928, Training Accuracy= 0.518
# Epoch: 410, Minibatch Loss= 0.6928, Training Accuracy= 0.528
# Epoch: 420, Minibatch Loss= 0.6928, Training Accuracy= 0.523
# Epoch: 430, Minibatch Loss= 0.6927, Training Accuracy= 0.522
# Epoch: 440, Minibatch Loss= 0.6927, Training Accuracy= 0.514
# Epoch: 450, Minibatch Loss= 0.6926, Training Accuracy= 0.516
# Epoch: 460, Minibatch Loss= 0.6915, Training Accuracy= 0.522
# Epoch: 470, Minibatch Loss= 0.5405, Training Accuracy= 0.710
# Epoch: 480, Minibatch Loss= 0.4490, Training Accuracy= 0.706
# Epoch: 490, Minibatch Loss= 0.1005, Training Accuracy= 0.966
# Epoch: 500, Minibatch Loss= 0.0721, Training Accuracy= 0.976
# Epoch: 510, Minibatch Loss= 0.0531, Training Accuracy= 0.979
# Epoch: 520, Minibatch Loss= 0.0315, Training Accuracy= 0.998
# Epoch: 530, Minibatch Loss= 0.0166, Training Accuracy= 1.000
# Epoch: 540, Minibatch Loss= 0.0112, Training Accuracy= 1.000
# Epoch: 550, Minibatch Loss= 0.0084, Training Accuracy= 1.000
# Epoch: 560, Minibatch Loss= 0.0066, Training Accuracy= 1.000
# Epoch: 570, Minibatch Loss= 0.0054, Training Accuracy= 1.000
# Epoch: 580, Minibatch Loss= 0.0046, Training Accuracy= 1.000
# Epoch: 590, Minibatch Loss= 0.0040, Training Accuracy= 1.000
# Epoch: 600, Minibatch Loss= 0.0035, Training Accuracy= 1.000
# Epoch: 610, Minibatch Loss= 0.0031, Training Accuracy= 1.000
# Epoch: 620, Minibatch Loss= 0.0028, Training Accuracy= 1.000
# Epoch: 630, Minibatch Loss= 0.0025, Training Accuracy= 1.000
# Epoch: 640, Minibatch Loss= 0.0023, Training Accuracy= 1.000
# Epoch: 650, Minibatch Loss= 0.0021, Training Accuracy= 1.000
# Epoch: 660, Minibatch Loss= 0.0020, Training Accuracy= 1.000
# Epoch: 670, Minibatch Loss= 0.0018, Training Accuracy= 1.000
# Epoch: 680, Minibatch Loss= 0.0017, Training Accuracy= 1.000
# Epoch: 690, Minibatch Loss= 0.0016, Training Accuracy= 1.000
# Epoch: 700, Minibatch Loss= 0.0015, Training Accuracy= 1.000
# Epoch: 710, Minibatch Loss= 0.0014, Training Accuracy= 1.000
# Epoch: 720, Minibatch Loss= 0.0013, Training Accuracy= 1.000
# Epoch: 730, Minibatch Loss= 0.0013, Training Accuracy= 1.000
# Epoch: 740, Minibatch Loss= 0.0012, Training Accuracy= 1.000
# Epoch: 750, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Epoch: 760, Minibatch Loss= 0.0011, Training Accuracy= 1.000
# Epoch: 770, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Epoch: 780, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Epoch: 790, Minibatch Loss= 0.0010, Training Accuracy= 1.000
# Epoch: 800, Minibatch Loss= 0.0009, Training Accuracy= 1.000
# Epoch: 810, Minibatch Loss= 0.0009, Training Accuracy= 1.000
# Epoch: 820, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Epoch: 830, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Epoch: 840, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Epoch: 850, Minibatch Loss= 0.0008, Training Accuracy= 1.000
# Epoch: 860, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Epoch: 870, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Epoch: 880, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Epoch: 890, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Epoch: 900, Minibatch Loss= 0.0007, Training Accuracy= 1.000
# Epoch: 910, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 920, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 930, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 940, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 950, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 960, Minibatch Loss= 0.0006, Training Accuracy= 1.000
# Epoch: 970, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 980, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 990, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 1000, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 1010, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 1020, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 1030, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 1040, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 1050, Minibatch Loss= 0.0005, Training Accuracy= 1.000
# Epoch: 1060, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1070, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1080, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1090, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1100, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1110, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1120, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1130, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1140, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1150, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1160, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1170, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1180, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1190, Minibatch Loss= 0.0004, Training Accuracy= 1.000
# Epoch: 1200, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1210, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1220, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1230, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1240, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1250, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1260, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1270, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1280, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1290, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1300, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1310, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1320, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1330, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1340, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1350, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1360, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1370, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1380, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1390, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1400, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1410, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1420, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1430, Minibatch Loss= 0.0003, Training Accuracy= 1.000
# Epoch: 1440, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1450, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1460, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1470, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1480, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1490, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1500, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1510, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1520, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1530, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1540, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1550, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1560, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1570, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1580, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1590, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1600, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1610, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1620, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1630, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1640, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1650, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1660, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1670, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1680, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1690, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1700, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1710, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1720, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1730, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1740, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1750, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1760, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1770, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1780, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1790, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1800, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1810, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1820, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1830, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1840, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1850, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1860, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1870, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1880, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1890, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1900, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1910, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1920, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1930, Minibatch Loss= 0.0002, Training Accuracy= 1.000
# Epoch: 1940, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 1950, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 1960, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 1970, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 1980, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 1990, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2000, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2010, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2020, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2030, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2040, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2050, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2060, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2070, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2080, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2090, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2100, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2110, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2120, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2130, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2140, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2150, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2160, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2170, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2180, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2190, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2200, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2210, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2220, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2230, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2240, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2250, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2260, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2270, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2280, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2290, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2300, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2310, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2320, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2330, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2340, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2350, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2360, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2370, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2380, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2390, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2400, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2410, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2420, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2430, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2440, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2450, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2460, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2470, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2480, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2490, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2500, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2510, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2520, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2530, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2540, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2550, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2560, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2570, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2580, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2590, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2600, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2610, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2620, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2630, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2640, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2650, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2660, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2670, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2680, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2690, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2700, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2710, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2720, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2730, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2740, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# Epoch: 2750, Minibatch Loss= 0.0001, Training Accuracy= 1.000
# ...
# Epoch: 1050, Minibatch Loss= 0.0683, Training Accuracy= 0.970
# Epoch: 1060, Minibatch Loss= 0.0707, Training Accuracy= 0.976
# Epoch: 1070, Minibatch Loss= 0.0567, Training Accuracy= 0.982
# Epoch: 1080, Minibatch Loss= 0.0424, Training Accuracy= 0.987
# Epoch: 1090, Minibatch Loss= 0.0323, Training Accuracy= 0.989
# Epoch: 1100, Minibatch Loss= 0.0278, Training Accuracy= 0.991
# Epoch: 1110, Minibatch Loss= 0.0248, Training Accuracy= 0.992
# Epoch: 1120, Minibatch Loss= 0.0217, Training Accuracy= 0.993
# Epoch: 1130, Minibatch Loss= 0.0190, Training Accuracy= 0.996
# Epoch: 1140, Minibatch Loss= 0.0173, Training Accuracy= 0.996
# Epoch: 1150, Minibatch Loss= 0.1919, Training Accuracy= 0.925
# Epoch: 1160, Minibatch Loss= 0.1569, Training Accuracy= 0.951
# Epoch: 1170, Minibatch Loss= 0.1451, Training Accuracy= 0.953
# Epoch: 1180, Minibatch Loss= 0.7026, Training Accuracy= 0.498
# Epoch: 1190, Minibatch Loss= 0.6999, Training Accuracy= 0.498
# Epoch: 1200, Minibatch Loss= 0.6993, Training Accuracy= 0.498
# Epoch: 1210, Minibatch Loss= 0.6991, Training Accuracy= 0.498
# Epoch: 1220, Minibatch Loss= 0.6989, Training Accuracy= 0.498
# Epoch: 1230, Minibatch Loss= 0.6988, Training Accuracy= 0.498
# Epoch: 1240, Minibatch Loss= 0.6988, Training Accuracy= 0.498
# Epoch: 1250, Minibatch Loss= 0.6987, Training Accuracy= 0.498
# Epoch: 1260, Minibatch Loss= 0.6987, Training Accuracy= 0.498
# Epoch: 1270, Minibatch Loss= 0.6987, Training Accuracy= 0.498
# Epoch: 1280, Minibatch Loss= 0.6987, Training Accuracy= 0.498
# Epoch: 1290, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1300, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1310, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1320, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1330, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1340, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1350, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1360, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1370, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1380, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1390, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1400, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1410, Minibatch Loss= 0.6986, Training Accuracy= 0.498
# Epoch: 1420, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1430, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1440, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1450, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1460, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1470, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1480, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1490, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1500, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1510, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1520, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1530, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1540, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1550, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1560, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1570, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1580, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1590, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1600, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1610, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1620, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1630, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1640, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1650, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1660, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1670, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1680, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1690, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1700, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1710, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1720, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1730, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1740, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1750, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1760, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1770, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1780, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1790, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1800, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1810, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1820, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1830, Minibatch Loss= 0.6985, Training Accuracy= 0.498
# Epoch: 1840, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1850, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1860, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1870, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1880, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1890, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1900, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1910, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1920, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1930, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1940, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1950, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1960, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1970, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1980, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 1990, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2000, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2010, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2020, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2030, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2040, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2050, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2060, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2070, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2080, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2090, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2100, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2110, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2120, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2130, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2140, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2150, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2160, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2170, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2180, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2190, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2200, Minibatch Loss= 0.6984, Training Accuracy= 0.498
# Epoch: 2210, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2220, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2230, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2240, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2250, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2260, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2270, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2280, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2290, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2300, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2310, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2320, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2330, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2340, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2350, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2360, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2370, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2380, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2390, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2400, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2410, Minibatch Loss= 0.6983, Training Accuracy= 0.498
# Epoch: 2420, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2430, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2440, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2450, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2460, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2470, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2480, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2490, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2500, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2510, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2520, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2530, Minibatch Loss= 0.6982, Training Accuracy= 0.498
# Epoch: 2540, Minibatch Loss= 0.6981, Training Accuracy= 0.498
# Epoch: 2550, Minibatch Loss= 0.6981, Training Accuracy= 0.498
# Epoch: 2560, Minibatch Loss= 0.6981, Training Accuracy= 0.498
# Epoch: 2570, Minibatch Loss= 0.6981, Training Accuracy= 0.498
# Epoch: 2580, Minibatch Loss= 0.6981, Training Accuracy= 0.498
# Epoch: 2590, Minibatch Loss= 0.6981, Training Accuracy= 0.498
# Epoch: 2600, Minibatch Loss= 0.6981, Training Accuracy= 0.498
# Epoch: 2610, Minibatch Loss= 0.6981, Training Accuracy= 0.498
# Epoch: 2620, Minibatch Loss= 0.6980, Training Accuracy= 0.498
# Epoch: 2630, Minibatch Loss= 0.6980, Training Accuracy= 0.498
# Epoch: 2640, Minibatch Loss= 0.6980, Training Accuracy= 0.498
# Epoch: 2650, Minibatch Loss= 0.6980, Training Accuracy= 0.498
# Epoch: 2660, Minibatch Loss= 0.6980, Training Accuracy= 0.498
# Epoch: 2670, Minibatch Loss= 0.6979, Training Accuracy= 0.498
# Epoch: 2680, Minibatch Loss= 0.6979, Training Accuracy= 0.498
# Epoch: 2690, Minibatch Loss= 0.6979, Training Accuracy= 0.498
# Epoch: 2700, Minibatch Loss= 0.6978, Training Accuracy= 0.498
# Epoch: 2710, Minibatch Loss= 0.6978, Training Accuracy= 0.498
# Epoch: 2720, Minibatch Loss= 0.6978, Training Accuracy= 0.498
# Epoch: 2730, Minibatch Loss= 0.6977, Training Accuracy= 0.498
# Epoch: 2740, Minibatch Loss= 0.6977, Training Accuracy= 0.498
# Epoch: 2750, Minibatch Loss= 0.6976, Training Accuracy= 0.498
# Epoch: 2760, Minibatch Loss= 0.6976, Training Accuracy= 0.498
# Epoch: 2770, Minibatch Loss= 0.6975, Training Accuracy= 0.498
# Epoch: 2780, Minibatch Loss= 0.6975, Training Accuracy= 0.498
# Epoch: 2790, Minibatch Loss= 0.6974, Training Accuracy= 0.498
# Epoch: 2800, Minibatch Loss= 0.6974, Training Accuracy= 0.498
# Epoch: 2810, Minibatch Loss= 0.6973, Training Accuracy= 0.498
# Epoch: 2820, Minibatch Loss= 0.6973, Training Accuracy= 0.498
# Epoch: 2830, Minibatch Loss= 0.6972, Training Accuracy= 0.498
# Epoch: 2840, Minibatch Loss= 0.6972, Training Accuracy= 0.498
# Epoch: 2850, Minibatch Loss= 0.6972, Training Accuracy= 0.498
# Epoch: 2860, Minibatch Loss= 0.6971, Training Accuracy= 0.498
# Epoch: 2870, Minibatch Loss= 0.6971, Training Accuracy= 0.498
# Epoch: 2880, Minibatch Loss= 0.6971, Training Accuracy= 0.498
# Epoch: 2890, Minibatch Loss= 0.6971, Training Accuracy= 0.498
# Epoch: 2900, Minibatch Loss= 0.6971, Training Accuracy= 0.498
# Epoch: 2910, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 2920, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 2930, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 2940, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 2950, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 2960, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 2970, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 2980, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 2990, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 3000, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 3010, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 3020, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 3030, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 3040, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 3050, Minibatch Loss= 0.6970, Training Accuracy= 0.498
# Epoch: 3060, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3070, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3080, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3090, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3100, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3110, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3120, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3130, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3140, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3150, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3160, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3170, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3180, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3190, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3200, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3210, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3220, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3230, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3240, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3250, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3260, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3270, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3280, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3290, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3300, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3310, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3320, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3330, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3340, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3350, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3360, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3370, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3380, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3390, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3400, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3410, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3420, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3430, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3440, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3450, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3460, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3470, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3480, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3490, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3500, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3510, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3520, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3530, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3540, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3550, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3560, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3570, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3580, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3590, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3600, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3610, Minibatch Loss= 0.6969, Training Accuracy= 0.498
# Epoch: 3620, Minibatch Loss= 0.6969, Training Accuracy= 0.498

# %%
# print results
test_accuracies_10replications_std = np.std(test_accuracies_10replications, axis=0)
test_accuracies_10replications_std_mean = test_accuracies_10replications_std / np.square(10)
print("test_accuracies_10replications: ", test_accuracies_10replications)
print("mean of test_accuracies_10replications: ", np.mean(test_accuracies_10replications))
print("standard deviation of test_accuracies_10replications_std_mean: ", test_accuracies_10replications_std_mean)

# %%
minibatch_losses_1st_replication
plt.plot(minibatch_losses_1st_replication, color='green', linewidth=5)
plt.plot(train_accuracies_1st_replication, color='blue', linewidth=7)
plt.plot(test_accuracies_1st_replication, color='red', linewidth=3)
plt.xlim(0, epochs)
plt.xlabel("epoch")
plt.ylim(0, 1.2)
plt.ylabel("train acc in blue, test acc in red, minibacth loss in green")
plt.title("1st replication")
plt.show()
