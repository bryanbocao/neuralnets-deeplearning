# %%
import numpy as np

# %%
data = np.loadtxt('assign1_data.txt')

# %%
print data
# Out:
# [[ 0.1227  0.299   0.1825  1.    ]
#  [ 0.3914  0.6392  0.8882  1.    ]
#  [ 0.7725  0.0826 -1.9521  0.    ]
#  [ 0.8342  0.0823 -1.9328  0.    ]
#  [ 0.5084  0.8025  1.2246  1.    ]
#  [ 0.9983  0.7404 -0.0631  0.    ]
#  [ 0.6643  0.3861 -0.4817  0.    ]
#  [ 0.0954  0.986   2.8156  1.    ]
#  [ 0.6949  0.605  -0.1065  0.    ]
#  [ 0.6075  0.3618 -0.7846  0.    ]
#  [ 0.3717  0.761   1.3196  1.    ]
#  [ 0.0193  0.7192  1.6524  1.    ]
#  [ 0.9314  0.5181 -0.8102  0.    ]
#  [ 0.2206  0.1091 -1.207   0.    ]
#  [ 0.0903  0.1085 -0.706   0.    ]
#  [ 0.5466  0.2028 -1.0808  0.    ]
#  [ 0.4331  0.7049  1.0344  1.    ]
#  [ 0.5293  0.688   0.5287  1.    ]
#  [ 0.8955  0.8477  0.7296  1.    ]
#  [ 0.0701  0.6176  1.4522  1.    ]
#  [ 0.0771  0.7883  1.8071  1.    ]
#  [ 0.1972  0.6273  1.2273  1.    ]
#  [ 0.6405  0.1157 -2.2342  0.    ]
#  [ 0.3203  0.2305 -0.5109  0.    ]
#  [ 0.103   0.314   0.1414  1.    ]
#  [ 0.5605  0.3131 -1.1836  0.    ]
#  [ 0.4288  0.9205  1.6718  1.    ]
# ...
